# %% [markdown]
# <a href="https://colab.research.google.com/github/errcr-exe/School-Shooting-Analysis/blob/Entrega2/Base_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_token = {
  "username": "n0yz10",
  "key": "b7f69a01c037cdefa5af44febf6b3319"}

# %%
# !rm -rf /root/.kaggle.

# %%
# !mkdir /root/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
import json
with open('/root/.kaggle/kaggle.json','w') as file:
  json.dump(api_token,file)

# %%
# !kaggle datasets download -d joebeachcapital/school-shootings
# Out:
# ...
# school-shootings.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

archivo_zip = '/content/school-shootings.zip'

with zipfile.ZipFile(archivo_zip, 'r') as zip_file:
  for nombre_archivo in zip_file.namelist():
    print(nombre_archivo)
# Out:
# record_layout.csv
# school-shootings-data.csv

# %%
nombre_archivo_cvs = 'school-shootings-data.csv'

with zipfile.ZipFile(archivo_zip, 'r') as zip_file:
  with zip_file.open(nombre_archivo_cvs) as archivo_csv:
    data = pd.read_csv(archivo_csv)

# %%
import pandas as pd

data.head()
# Out:
#    uid nces_school_id                  school_name  nces_district_id  \
# 0    1   080480000707        Columbine High School          804800.0
# 1    2   220054000422  Scotlandville Middle School         2200540.0
# 2    3   130441001591         Heritage High School         1304410.0
# 3    4   421899003847     John Bartram High School         4218990.0
# 4    5   250279000225       Dorchester High School         2502790.0
#
#                           district_name       date school_year  year  \
# 0                  Jefferson County R-1  4/20/1999   1998-1999  1999
# 1  East Baton Rouge Parish School Board  4/22/1999   1998-1999  1999
# 2                       Rockdale County  5/20/1999   1998-1999  1999
# 3                  Philadelphia City SD  10/4/1999   1999-2000  1999
# 4                                Boston  11/3/1999   1999-2000  1999
#
#        time day_of_week  ...        lat        long staffing low_grade  \
# ...
